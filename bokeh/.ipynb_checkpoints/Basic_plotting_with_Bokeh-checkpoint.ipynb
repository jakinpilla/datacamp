# %%
from bokeh.plotting import figure

# %%
from bokeh.io import output_file, show

# %%
# Create the figure:p
p = figure(x_axis_label = 'fertility (children per women)',
          y_axis_label = 'female_literacy (% population)')

# %%
pwd()
# Out:
# 'C:\\Users\\Daniel\\datacamp\\bokeh'

# %%
import numpy as np
import pandas as pd

# %%
df_tmp = pd.read_csv('./data/literacy_birth_rate.csv')

# %%
fertility = df_tmp.fertility.tolist()

# %%
fertility[1:10]
# Out:
# ['2.682',
#  '2.077',
#  '2.132',
#  '1.827',
#  '3.872',
#  '2.288',
#  '5.173',
#  '1.393',
#  '1.262']

# %%
len(fertility)
# Out:
# 182

# %%
df_tmp.columns
# Out:
# Index(['Country ', 'Continent', 'female literacy', 'fertility', 'population'], dtype='object')

# %%
female_literacy_series = df_tmp['female literacy']

# %%
female_literacy = female_literacy_series.tolist()

# %%
female_literacy[1:10]
# Out:
# ['50.8', '99', '88.8', '90.2', '40', '49.8', '48.8', '99.4', '99']

# %%
len(female_literacy)
# Out:
# 182

# %%
# ADd a circle glyph to the figure p
p.circle(fertility, female_literacy)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='3a96c420-7bef-4994-b929-23ed67e87601',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='b3f32894-8a79-475b-9bdf-06130789c5ac',
#         callback=None,
#         data={'y': ['90.5',
#           '50.8',
#           '99',
#           '88.8',
#           '90.2',
#           '40',
#           '49.8',
#           '48.8',
#           '99.4',
#           '99',
#           '91.5',
#           '93.9',
#           '90.2',
#           '99',
#           '57.8',
#           '22.8',
#           '81.3',
#           '77.2',
#           '91.5',
#           '56.1',
#           '99',
#           '99',
#           '98.5',
#           '89.2',
#           '88.1',
#           '96.6',
#           '99.6',
#           '96.9',
#           '93.4',
#           '66.3',
#           '59.6',
#           '97.7',
#           '82.8',
#           '99.3',
#           '63.9',
#           '99',
#           '66.8',
#           '44.1',
#           '69.2',
#           '12.6',
#           '84.6',
#           '45.4',
#           '94.9',
#           '98.9',
#           '89.8',
#           '80.2',
#           '100',
#           '59.3',
#           '42.8',
#           '40.1',
#           '96.9',
#           '44.3',
#           '77.2',
#           '89.1',
#           '65.3',
#           '67.8',
#           '57',
#           '98.7',
#           '99',
#           '99.5',
#           '21.6',
#           '65.8',
#           '15.1',
#           '70.9',
#           '68.7',
#           '81.7',
#           '18.2',
#           '61',
#           '88.8',
#           '33',
#           '95.9',
#           '99.8',
#           '21.9',
#           '99',
#           '92.9',
#           '99',
#           '71',
#           '98.9',
#           '88.3',
#           '26.4',
#           '66.1',
#           '86',
#           '99.7',
#           '99',
#           '99.2',
#           '28.1',
#           '59.9',
#           '99',
#           '97.9',
#           '96.2',
#           '83.5',
#           '95.9',
#           '99.5',
#           '55.6',
#           '53.7',
#           '81.3',
#           '93.5',
#           '63.2',
#           '81.4',
#           '88.9',
#           '77.9',
#           '28.9',
#           '99',
#           '100',
#           '99.1',
#           '99.3',
#           '54.5',
#           '91.6',
#           '100',
#           '96.2',
#           '91.5',
#           '98',
#           '99',
#           '41.1',
#           '99.7',
#           '99',
#           '86',
#           '53',
#           '95.9',
#           '97.8',
#           '92.8',
#           '99.7',
#           '98.5',
#           '49.5',
#           '98.7',
#           '99.4',
#           '80.9',
#           '93.1',
#           '90.8',
#           '97.8',
#           '99.8',
#           '87.7',
#           '95.1',
#           '95.4',
#           '99.7',
#           '83.5',
#           '34.3',
#           '36.5',
#           '83.2',
#           '99.8',
#           '98.2',
#           '90.4',
#           '84.8',
#           '85.6',
#           '96.7',
#           '89.4',
#           '38.7',
#           '89.1',
#           '67.8',
#           '90.7',
#           '88.4',
#           '79.3',
#           '93.5',
#           '93.3',
#           '96.5',
#           '99',
#           '98.4',
#           '79.5',
#           '98.5',
#           '83.3',
#           '98',
#           '99.1',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'female literacy',
#           '99.4',
#           '96.3',
#           '99',
#           '92.3',
#           '90.9',
#           '77'],
#          'x': ['1.769',
#           '2.682',
#           '2.077',
#           '2.132',
#           '1.827',
#           '3.872',
#           '2.288',
#           '5.173',
#           '1.393',
#           '1.262',
#           '2.156',
#           '3.026',
#           '2.033',
#           '1.324',
#           '2.816',
#           '5.211',
#           '2.1',
#           '1.781',
#           '1.822',
#           '5.908',
#           '1.881',
#           '1.852',
#           '1.39',
#           '2.281',
#           '2.505',
#           '1.224',
#           '1.361',
#           '1.468',
#           '2.404',
#           '5.52',
#           '4.058',
#           '2.223',
#           '4.859',
#           '1.267',
#           '2.342',
#           '1.579',
#           '6.254',
#           '2.334',
#           '3.961',
#           '6.505',
#           '2.53',
#           '2.823',
#           '2.498',
#           '2.248',
#           '2.508',
#           '3.04',
#           '1.854',
#           '4.22',
#           '5.1',
#           '4.967',
#           '1.325',
#           '4.514',
#           '3.173',
#           '2.308',
#           '4.62',
#           '4.541',
#           '5.637',
#           '1.926',
#           '1.747',
#           '2.294',
#           '5.841',
#           '5.455',
#           '7.069',
#           '2.859',
#           '4.018',
#           '2.513',
#           '5.405',
#           '5.737',
#           '3.363',
#           '4.89',
#           '1.385',
#           '1.505',
#           '6.081',
#           '1.784',
#           '1.378',
#           '1.45',
#           '1.841',
#           '1.37',
#           '2.612',
#           '5.329',
#           '5.33',
#           '3.371',
#           '1.281',
#           '1.871',
#           '2.153',
#           '5.378',
#           '4.45',
#           '1.46',
#           '1.436',
#           '1.612',
#           '3.19',
#           '2.752',
#           '3.35',
#           '4.01',
#           '4.166',
#           '2.642',
#           '2.977',
#           '3.415',
#           '2.295',
#           '3.019',
#           '2.683',
#           '5.165',
#           '1.849',
#           '1.836',
#           '2.518',
#           '2.43',
#           '4.528',
#           '1.263',
#           '1.885',
#           '1.943',
#           '1.899',
#           '1.442',
#           '1.953',
#           '4.697',
#           '1.582',
#           '2.025',
#           '1.841',
#           '5.011',
#           '1.212',
#           '1.502',
#           '2.516',
#           '1.367',
#           '2.089',
#           '4.388',
#           '1.854',
#           '1.748',
#           '2.978',
#           '2.152',
#           '2.362',
#           '1.988',
#           '1.426',
#           '3.29',
#           '3.264',
#           '1.436',
#           '1.393',
#           '2.822',
#           '4.969',
#           '5.659',
#           '3.24',
#           '1.693',
#           '1.647',
#           '2.36',
#           '1.792',
#           '3.45',
#           '1.516',
#           '2.233',
#           '2.563',
#           '5.283',
#           '3.885',
#           '0.966',
#           '2.373',
#           '2.663',
#           '1.251',
#           '2.052',
#           '3.371',
#           '2.093',
#           '2',
#           '3.883',
#           '3.852',
#           '3.718',
#           '1.732',
#           '3.928',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'fertility',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN',
#           'NaN']},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='d52f73c3-0573-4b1c-85da-14fcba10ee2d',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='ff7cd6b9-b1f0-49c8-83a1-07b0aed6d66b',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='34ebdff7-9609-4ddb-97fc-0044646dad46',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='1f26db21-f205-497e-81c4-59c5feea8741',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='bd8e22e6-892f-436b-b6c6-9060b253ef60',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='b3f32894-8a79-475b-9bdf-06130789c5ac',
#             callback=None,
#             data={'y': ['90.5',
#               '50.8',
#               '99',
#               '88.8',
#               '90.2',
#               '40',
#               '49.8',
#               '48.8',
#               '99.4',
#               '99',
#               '91.5',
#               '93.9',
#               '90.2',
#               '99',
#               '57.8',
#               '22.8',
#               '81.3',
#               '77.2',
#               '91.5',
#               '56.1',
#               '99',
#               '99',
#               '98.5',
#               '89.2',
#               '88.1',
#               '96.6',
#               '99.6',
#               '96.9',
#               '93.4',
#               '66.3',
#               '59.6',
#               '97.7',
#               '82.8',
#               '99.3',
#               '63.9',
#               '99',
#               '66.8',
#               '44.1',
#               '69.2',
#               '12.6',
#               '84.6',
#               '45.4',
#               '94.9',
#               '98.9',
#               '89.8',
#               '80.2',
#               '100',
#               '59.3',
#               '42.8',
#               '40.1',
#               '96.9',
#               '44.3',
#               '77.2',
#               '89.1',
#               '65.3',
#               '67.8',
#               '57',
#               '98.7',
#               '99',
#               '99.5',
#               '21.6',
#               '65.8',
#               '15.1',
#               '70.9',
#               '68.7',
#               '81.7',
#               '18.2',
#               '61',
#               '88.8',
#               '33',
#               '95.9',
#               '99.8',
#               '21.9',
#               '99',
#               '92.9',
#               '99',
#               '71',
#               '98.9',
#               '88.3',
#               '26.4',
#               '66.1',
#               '86',
#               '99.7',
#               '99',
#               '99.2',
#               '28.1',
#               '59.9',
#               '99',
#               '97.9',
#               '96.2',
#               '83.5',
#               '95.9',
#               '99.5',
#               '55.6',
#               '53.7',
#               '81.3',
#               '93.5',
#               '63.2',
#               '81.4',
#               '88.9',
#               '77.9',
#               '28.9',
#               '99',
#               '100',
#               '99.1',
#               '99.3',
#               '54.5',
#               '91.6',
#               '100',
#               '96.2',
#               '91.5',
#               '98',
#               '99',
#               '41.1',
#               '99.7',
#               '99',
#               '86',
#               '53',
#               '95.9',
#               '97.8',
#               '92.8',
#               '99.7',
#               '98.5',
#               '49.5',
#               '98.7',
#               '99.4',
#               '80.9',
#               '93.1',
#               '90.8',
#               '97.8',
#               '99.8',
#               '87.7',
#               '95.1',
#               '95.4',
#               '99.7',
#               '83.5',
#               '34.3',
#               '36.5',
#               '83.2',
#               '99.8',
#               '98.2',
#               '90.4',
#               '84.8',
#               '85.6',
#               '96.7',
#               '89.4',
#               '38.7',
#               '89.1',
#               '67.8',
#               '90.7',
#               '88.4',
#               '79.3',
#               '93.5',
#               '93.3',
#               '96.5',
#               '99',
#               '98.4',
#               '79.5',
#               '98.5',
#               '83.3',
#               '98',
#               '99.1',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'female literacy',
#               '99.4',
#               '96.3',
#               '99',
#               '92.3',
#               '90.9',
#               '77'],
#              'x': ['1.769',
#               '2.682',
#               '2.077',
#               '2.132',
#               '1.827',
#               '3.872',
#               '2.288',
#               '5.173',
#               '1.393',
#               '1.262',
#               '2.156',
#               '3.026',
#               '2.033',
#               '1.324',
#               '2.816',
#               '5.211',
#               '2.1',
#               '1.781',
#               '1.822',
#               '5.908',
#               '1.881',
#               '1.852',
#               '1.39',
#               '2.281',
#               '2.505',
#               '1.224',
#               '1.361',
#               '1.468',
#               '2.404',
#               '5.52',
#               '4.058',
#               '2.223',
#               '4.859',
#               '1.267',
#               '2.342',
#               '1.579',
#               '6.254',
#               '2.334',
#               '3.961',
#               '6.505',
#               '2.53',
#               '2.823',
#               '2.498',
#               '2.248',
#               '2.508',
#               '3.04',
#               '1.854',
#               '4.22',
#               '5.1',
#               '4.967',
#               '1.325',
#               '4.514',
#               '3.173',
#               '2.308',
#               '4.62',
#               '4.541',
#               '5.637',
#               '1.926',
#               '1.747',
#               '2.294',
#               '5.841',
#               '5.455',
#               '7.069',
#               '2.859',
#               '4.018',
#               '2.513',
#               '5.405',
#               '5.737',
#               '3.363',
#               '4.89',
#               '1.385',
#               '1.505',
#               '6.081',
#               '1.784',
#               '1.378',
#               '1.45',
#               '1.841',
#               '1.37',
#               '2.612',
#               '5.329',
#               '5.33',
#               '3.371',
#               '1.281',
#               '1.871',
#               '2.153',
#               '5.378',
#               '4.45',
#               '1.46',
#               '1.436',
#               '1.612',
#               '3.19',
#               '2.752',
#               '3.35',
#               '4.01',
#               '4.166',
#               '2.642',
#               '2.977',
#               '3.415',
#               '2.295',
#               '3.019',
#               '2.683',
#               '5.165',
#               '1.849',
#               '1.836',
#               '2.518',
#               '2.43',
#               '4.528',
#               '1.263',
#               '1.885',
#               '1.943',
#               '1.899',
#               '1.442',
#               '1.953',
#               '4.697',
#               '1.582',
#               '2.025',
#               '1.841',
#               '5.011',
#               '1.212',
#               '1.502',
#               '2.516',
#               '1.367',
#               '2.089',
#               '4.388',
#               '1.854',
#               '1.748',
#               '2.978',
#               '2.152',
#               '2.362',
#               '1.988',
#               '1.426',
#               '3.29',
#               '3.264',
#               '1.436',
#               '1.393',
#               '2.822',
#               '4.969',
#               '5.659',
#               '3.24',
#               '1.693',
#               '1.647',
#               '2.36',
#               '1.792',
#               '3.45',
#               '1.516',
#               '2.233',
#               '2.563',
#               '5.283',
#               '3.885',
#               '0.966',
#               '2.373',
#               '2.663',
#               '1.251',
#               '2.052',
#               '3.371',
#               '2.093',
#               '2',
#               '3.883',
#               '3.852',
#               '3.718',
#               '1.732',
#               '3.928',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'fertility',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN',
#               'NaN']},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='d52f73c3-0573-4b1c-85da-14fcba10ee2d',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='ff7cd6b9-b1f0-49c8-83a1-07b0aed6d66b',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
output_file('fert_lit.html')

# %%
show(p)

# %%
# Scatter plot with different shapes

# %%
df_tmp.head()
# Out:
#     Country  Continent female literacy fertility    population
# 0      Chine       ASI            90.5     1.769  1.324655e+09
# 1       Inde       ASI            50.8     2.682  1.139965e+09
# 2        USA       NAM              99     2.077  3.040600e+08
# 3  Indonésie       ASI            88.8     2.132  2.273451e+08
# 4     Brésil       LAT            90.2     1.827  1.919715e+08

# %%
df_tmp.Continent.value_counts()
# Out:
# AF           49
# ASI          47
# EUR          36
# LAT          24
# OCE           4
# NAM           2
# WORLD         1
# Continent     1
# Name: Continent, dtype: int64

# %%
fertility_africa = df_tmp[df_tmp['Continent'] == 'AF']['fertility'].tolist()

# %%
fertility_africa; len(fertility_africa)
# Out:
# 49

# %%
female_literacy_africa = df_tmp[df_tmp['Continent'] == 'AF']['female literacy'].tolist()

# %%
female_literacy_africa; len(female_literacy_africa)
# Out:
# 49

# %%
fertility_latinamerica = df_tmp[df_tmp['Continent'] == 'LAT']['fertility'].tolist()

# %%
fertility_latinamerica; len(fertility_latinamerica)
# Out:
# 24

# %%
female_literacy_latinamerica = df_tmp[df_tmp['Continent'] == 'LAT']['female literacy'].tolist()

# %%
female_literacy_latinamerica; len(female_literacy_latinamerica)
# Out:
# 24

# %%
p = figure(x_axis_label = 'fertility', 
          y_axis_label = 'female_literacy (%population)')

# %%
p.circle(fertility_latinamerica,
        female_literacy_latinamerica)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='b6a895f0-5de3-41f5-97f3-56efb5d60ab6',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='18af4640-e0cd-4e2c-931e-5bc2e39c738f',
#         callback=None,
#         data={'y': ['90.2',
#           '91.5',
#           '93.4',
#           '97.7',
#           '84.6',
#           '94.9',
#           '98.7',
#           '68.7',
#           '81.7',
#           '99.8',
#           '88.3',
#           '86',
#           '83.5',
#           '93.5',
#           '81.4',
#           '77.9',
#           '96.2',
#           '92.8',
#           '98.5',
#           '90.8',
#           '98.2',
#           '88.4',
#           '96.5',
#           '98'],
#          'x': ['1.827',
#           '2.156',
#           '2.404',
#           '2.223',
#           '2.53',
#           '2.498',
#           '1.926',
#           '4.018',
#           '2.513',
#           '1.505',
#           '2.612',
#           '3.371',
#           '3.19',
#           '2.977',
#           '2.295',
#           '2.683',
#           '1.943',
#           '2.516',
#           '2.089',
#           '2.362',
#           '1.647',
#           '2.373',
#           '3.371',
#           '1.732']},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='e91648cb-d9bc-4d8c-9255-cdefdfe21124',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='1bbc786b-a4fc-4d47-b4f5-5ef37148b179',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='8823f82a-eb87-4cb1-a94c-cb2f2623a1eb',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='36cdbab9-c1df-47e4-ace5-32c666a05754',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='668abe71-05d4-4f29-bb34-4e4206e530b4',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='18af4640-e0cd-4e2c-931e-5bc2e39c738f',
#             callback=None,
#             data={'y': ['90.2',
#               '91.5',
#               '93.4',
#               '97.7',
#               '84.6',
#               '94.9',
#               '98.7',
#               '68.7',
#               '81.7',
#               '99.8',
#               '88.3',
#               '86',
#               '83.5',
#               '93.5',
#               '81.4',
#               '77.9',
#               '96.2',
#               '92.8',
#               '98.5',
#               '90.8',
#               '98.2',
#               '88.4',
#               '96.5',
#               '98'],
#              'x': ['1.827',
#               '2.156',
#               '2.404',
#               '2.223',
#               '2.53',
#               '2.498',
#               '1.926',
#               '4.018',
#               '2.513',
#               '1.505',
#               '2.612',
#               '3.371',
#               '3.19',
#               '2.977',
#               '2.295',
#               '2.683',
#               '1.943',
#               '2.516',
#               '2.089',
#               '2.362',
#               '1.647',
#               '2.373',
#               '3.371',
#               '1.732']},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='e91648cb-d9bc-4d8c-9255-cdefdfe21124',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='1bbc786b-a4fc-4d47-b4f5-5ef37148b179',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
p.x(fertility_africa, female_literacy_africa)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='e3c3c0e1-5d63-486f-a2c8-00ba4301bcb9',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='aca62e4e-c1dd-49b4-b535-65332dbf4f17',
#         callback=None,
#         data={'y': ['48.8',
#           '57.8',
#           '22.8',
#           '56.1',
#           '88.1',
#           '66.3',
#           '59.6',
#           '82.8',
#           '63.9',
#           '66.8',
#           '44.1',
#           '59.3',
#           '40.1',
#           '44.3',
#           '65.3',
#           '67.8',
#           '57',
#           '21.6',
#           '65.8',
#           '15.1',
#           '18.2',
#           '61',
#           '88.8',
#           '33',
#           '21.9',
#           '71',
#           '26.4',
#           '66.1',
#           '28.1',
#           '59.9',
#           '53.7',
#           '81.3',
#           '28.9',
#           '54.5',
#           '41.1',
#           '53',
#           '49.5',
#           '87.7',
#           '95.1',
#           '83.5',
#           '34.3',
#           '36.5',
#           '83.2',
#           '84.8',
#           '85.6',
#           '89.1',
#           '67.8',
#           '79.3',
#           '83.3'],
#          'x': ['5.173',
#           '2.816',
#           '5.211',
#           '5.908',
#           '2.505',
#           '5.52',
#           '4.058',
#           '4.859',
#           '2.342',
#           '6.254',
#           '2.334',
#           '4.22',
#           '4.967',
#           '4.514',
#           '4.62',
#           '4.541',
#           '5.637',
#           '5.841',
#           '5.455',
#           '7.069',
#           '5.405',
#           '5.737',
#           '3.363',
#           '4.89',
#           '6.081',
#           '1.841',
#           '5.329',
#           '5.33',
#           '5.378',
#           '4.45',
#           '4.166',
#           '2.642',
#           '5.165',
#           '4.528',
#           '4.697',
#           '5.011',
#           '4.388',
#           '3.29',
#           '3.264',
#           '2.822',
#           '4.969',
#           '5.659',
#           '3.24',
#           '1.792',
#           '3.45',
#           '5.283',
#           '3.885',
#           '2.663',
#           '3.718']},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='a0159490-ec99-4cd9-a9fd-e7c03749e9eb',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='2e596ac9-71dd-48c6-84b0-708456c9ab84',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.X(
#         id='1f718d52-4540-4fe2-aff0-b50974e9e16f',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.X(
#         id='bf1a259e-7c11-4473-83b8-b2291262e74a',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='cada4a3e-61fa-478c-bb5e-2e7774ff382a',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='aca62e4e-c1dd-49b4-b535-65332dbf4f17',
#             callback=None,
#             data={'y': ['48.8',
#               '57.8',
#               '22.8',
#               '56.1',
#               '88.1',
#               '66.3',
#               '59.6',
#               '82.8',
#               '63.9',
#               '66.8',
#               '44.1',
#               '59.3',
#               '40.1',
#               '44.3',
#               '65.3',
#               '67.8',
#               '57',
#               '21.6',
#               '65.8',
#               '15.1',
#               '18.2',
#               '61',
#               '88.8',
#               '33',
#               '21.9',
#               '71',
#               '26.4',
#               '66.1',
#               '28.1',
#               '59.9',
#               '53.7',
#               '81.3',
#               '28.9',
#               '54.5',
#               '41.1',
#               '53',
#               '49.5',
#               '87.7',
#               '95.1',
#               '83.5',
#               '34.3',
#               '36.5',
#               '83.2',
#               '84.8',
#               '85.6',
#               '89.1',
#               '67.8',
#               '79.3',
#               '83.3'],
#              'x': ['5.173',
#               '2.816',
#               '5.211',
#               '5.908',
#               '2.505',
#               '5.52',
#               '4.058',
#               '4.859',
#               '2.342',
#               '6.254',
#               '2.334',
#               '4.22',
#               '4.967',
#               '4.514',
#               '4.62',
#               '4.541',
#               '5.637',
#               '5.841',
#               '5.455',
#               '7.069',
#               '5.405',
#               '5.737',
#               '3.363',
#               '4.89',
#               '6.081',
#               '1.841',
#               '5.329',
#               '5.33',
#               '5.378',
#               '4.45',
#               '4.166',
#               '2.642',
#               '5.165',
#               '4.528',
#               '4.697',
#               '5.011',
#               '4.388',
#               '3.29',
#               '3.264',
#               '2.822',
#               '4.969',
#               '5.659',
#               '3.24',
#               '1.792',
#               '3.45',
#               '5.283',
#               '3.885',
#               '2.663',
#               '3.718']},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='a0159490-ec99-4cd9-a9fd-e7c03749e9eb',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='2e596ac9-71dd-48c6-84b0-708456c9ab84',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
output_file('fert_lit_separate.html')

# %%
show(p)
